# %%
import pandas as pd

# %%
mass_shootings_df = pd.read_csv("Stanford_MSA_Database.csv")
mass_shootings_df.set_index("CaseID", inplace=True)
mass_shootings_df.head()
# Out:
#                                  Title                Location         City  \
# CaseID
# 1        University of Texas at Austin           Austin, Texas       Austin
# 2           Rose-Mar College of Beauty           Mesa, Arizona         Mesa
# 3         New Orleans Police Shootings  New Orleans, Louisiana  New Orleans
# 4       Clara Barton Elementary School       Chicago, Illinois      Chicago
# 5                    Olean High School         Olean, New York        Olean
#
#             State   Latitude   Longitude  Number of Civilian Fatalities  \
# CaseID
# 1           Texas  30.198887  -97.844159                             15
# 2         Arizona  33.422687 -111.816320                              5
# 3       Louisiana  30.068724  -89.931474                              4
# 4        Illinois  41.839280  -87.688181                              1
# 5        New York  42.081854  -78.432139                              3
#
# ...
